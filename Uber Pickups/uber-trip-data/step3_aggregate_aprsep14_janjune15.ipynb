# %%
import pandas as pd
result14=pd.read_csv("/Users/fezzibasma/Desktop/Data Full-Stack/Machine Learning Unsupervised/Projet Uber/export_step/formatting_aprsep14.csv",index_col=[0])
result15=pd.read_csv("/Users/fezzibasma/Desktop/Data Full-Stack/Machine Learning Unsupervised/Projet Uber/export_step/formatting_janjune15.csv",index_col=[0])

# %%
result14.head()
# Out:
#        Date     Time  locationID    Base    Lon    Lat    Borough  \
# 0  9/1/2014  0:03:00        48.0  B02512 -73.99  40.76  Manhattan
# 1  9/1/2014  0:33:00       161.0  B02512 -73.98  40.76  Manhattan
# 2  9/1/2014  0:33:00       230.0  B02512 -73.98  40.76  Manhattan
# 3  9/1/2014  0:37:00       166.0  B02512 -73.96  40.81  Manhattan
# 4  9/1/2014  0:48:00       114.0  B02512 -73.99  40.72  Manhattan
#
#                         Zone
# 0               Clinton East
# 1             Midtown Center
# 2  Times Sq/Theatre District
# 3        Morningside Heights
# 4    Greenwich Village South

# %%
result14['Lat'].isnull().value_counts()
# Out:
# False    1057672
# Name: Lat, dtype: int64

# %%
result15.head()
# Out:
#        Date      Time  locationID    Base    Lon    Lat    Borough  \
# 0  17/05/15  09:47:00         141  B02617 -73.96  40.76  Manhattan
# 1  17/05/15  09:47:00          65  B02617 -73.99  40.70   Brooklyn
# 2  17/05/15  09:47:00         100  B02617 -73.99  40.75  Manhattan
# 3  17/05/15  09:47:00          80  B02774 -73.93  40.73   Brooklyn
# 4  17/05/15  09:47:00          90  B02617 -74.00  40.74  Manhattan
#
#                           Zone
# 0              Lenox Hill West
# 1  Downtown Brooklyn/MetroTech
# 2             Garment District
# 3            East Williamsburg
# 4                     Flatiron

# %%
result15['Lat'].isnull().value_counts()
# Out:
# False    14110013
# Name: Lat, dtype: int64

# %%
result1415=pd.concat([result14,result15],axis=0)

# %%
result1415
# Out:
#               Date      Time  locationID    Base    Lon    Lat    Borough  \
# 0         9/1/2014   0:03:00        48.0  B02512 -73.99  40.76  Manhattan
# 1         9/1/2014   0:33:00       161.0  B02512 -73.98  40.76  Manhattan
# 2         9/1/2014   0:33:00       230.0  B02512 -73.98  40.76  Manhattan
# 3         9/1/2014   0:37:00       166.0  B02512 -73.96  40.81  Manhattan
# 4         9/1/2014   0:48:00       114.0  B02512 -73.99  40.72  Manhattan
# ...            ...       ...         ...     ...    ...    ...        ...
# 14278841  08/05/15  15:43:00       186.0  B02765 -73.99  40.75  Manhattan
# 14278842  08/05/15  15:43:00       263.0  B02765 -73.95  40.77  Manhattan
# 14278843  08/05/15  15:43:00        90.0  B02765 -74.00  40.74  Manhattan
# 14278844  08/05/15  15:44:00        45.0  B01899 -74.00  40.71  Manhattan
# 14278845  08/05/15  15:44:00       144.0  B02682 -74.00  40.72  Manhattan
#
#                                   Zone
# 0                         Clinton East
# ...

# %%
result1415['Lat'].isnull().value_counts()
# Out:
# False    15167685
# Name: Lat, dtype: int64

# %%
file_name = '/Users/fezzibasma/Desktop/Data Full-Stack/Machine Learning Unsupervised/Projet Uber/export_step/aggregate_1415.csv'
result1415.to_csv(file_name)
print('File is written to CSV File successfully.')
# Out:
# File is written to CSV File successfully.
